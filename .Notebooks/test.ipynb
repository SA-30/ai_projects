# %%
import TTS
print(TTS.__version__)

# %%
from TTS.api import TTS

# %%
# List available models
TTS.list_models()

# %%
# Load a British English model with a male voice (example model)
tts = TTS(model_name="tts_models/en/ek1/tacotron2")

# %%
# Synthesize
tts.tts_to_file(text="Hello, this is a British male voice.", file_path="british_male.wav")
